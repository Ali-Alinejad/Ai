# %%
import matplotlib.pyplot as  plt
import pandas as pd
import numpy as np
import sklearn as skl

# %%
years = np.array([0,1,2,3,4,6,8,10]).reshape(-1,1)
salaries = np.array([30000,40000,55000,60000,70000,80000,85000,87000])

# %%
plt.plot(years,salaries)
